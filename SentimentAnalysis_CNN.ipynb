# %%
import cPickle
import numpy as np
import tensorflow as tf

print "loading data..."
x = cPickle.load(open("Data/imdb-train-val-test.pickle", "rb"))
revs, word2vec, word_idx_map = x[0], x[1], x[2]
print "data loaded!"
# Out:
# loading data...
# data loaded!

# %%
def split_train_valid_test(revs, train_ratio=0.8, valid_ratio=0.05, test_ratio=0.15):
    n_train=int(len(revs)*0.65)
    n_valid=int(len(revs)*0.15)
    train, valid, test=[], [], []
    for i in range(len(revs)):
        if i<n_train:
            train.append(revs[i])
        elif i<n_train+n_valid:
            valid.append(revs[i])
        else:
            test.append(revs[i])
    return train, valid, test

train, valid, test=split_train_valid_test(revs)    
print("Training size {}, validation size {}, test size {}".format(len(train), \
                                                                  len(valid), len(test)))
# Out:
# Training size 130000, validation size 30000, test size 40000

# %%
import pandas as pd
max_sentence_len=np.max((pd.DataFrame(revs)['num_words']))
print("The longest sentence has {} words".format(max_sentence_len))
# Out:
# The longest sentence has 105 words

# %%
# del revs

# %%
def sentence2_1hot(sentence, dictionary, max_length):
    V=np.zeros(shape=max_length, dtype=np.int32)
    i=0
    for word in sentence.split():
        if i>=max_length:
            break
        V[i]=dictionary[word]
        i+=1
    return V

# %%
word2vec.shape
# Out:
# (150855, 300)

# %%
def embedding_batch(revs, W, word_idx_map, max_sentence_len, batch_size=50, batch_index=0):
    tail=batch_size*(batch_index+1)
    assert tail<=len(revs)
    embedded=np.zeros(shape=(batch_size, max_sentence_len, 300), dtype=np.float64)
    labels=np.zeros(shape=batch_size, dtype=np.int32)
    k=0
    for i in range(tail-batch_size, tail):
        sentence_1hot=sentence2_1hot(revs[i]['text'], word_idx_map, max_sentence_len)
        for j in range(len(sentence_1hot)):
            embedded[k][j][:]=W[sentence_1hot[j]]
        labels[k]=int(revs[i]['y']*0.25)
        k+=1
    return embedded, labels

# %%
#####################################################
#Define a DNN class that can be used in sklearn randomized search
#####################################################
from tensorflow.contrib.layers import batch_norm
from tensorflow.contrib.layers import fully_connected
import tensorflow as tf 
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
import time
from sklearn.base import BaseEstimator, TransformerMixin
he_init = tf.contrib.layers.variance_scaling_initializer()
class My_DNN(BaseEstimator, TransformerMixin):
    def __init__(self, data, W, n_input=30*300, n_output=2, \
                 n_neurons=140, n_layers=5, learning_rate=0.01, n_epoches=1000,\
                 batch_size=200,batch_norm_momentum=0.99, dropout_rate=0.5, \
                 activation=tf.nn.elu, initializer=he_init):
        self.W=W #word2vec
        self.data=data
        self.n_input=n_input
        self.n_output=n_output
        self.n_neurons=n_neurons
        self.n_layers=n_layers
        self.learning_rate=learning_rate
        self.n_epoches=n_epoches
        self.batch_size=batch_size
        self.batch_norm_momentum=batch_norm_momentum
        self.dropout_rate=dropout_rate
        self.activation=activation
        self.initializer=initializer
        self._session = None
    
    def build_hidden_layers(self, input):
        is_training=tf.placeholder_with_default(False, shape=(), name='training')
        for layer in range(self.n_layers-1):
            if(self.dropout_rate!=None):
                input=tf.layers.dropout(input, self.dropout_rate, training=is_training)
            input=tf.layers.dense(input, self.n_neurons, activation=self.activation,\
                                          kernel_initializer=self.initializer)
            if(self.batch_norm_momentum!=None):
                input=tf.layers.batch_normalization(input, momentum=self.batch_norm_momentum, training=is_training)
        self.is_training=is_training
        return input
    
    def build_graph(self):
        X=tf.placeholder(tf.float32, shape=(None, self.n_input), name='tweets')
        y=tf.placeholder(tf.int64, shape=(None), name='sentiment')       
        output=self.build_hidden_layers(X)
        logits=tf.layers.dense(output, self.n_output, activation=tf.nn.softmax, kernel_initializer=self.initializer)
        xentropy=tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
        loss=tf.reduce_mean(xentropy, name='loss')
        optimizer=tf.train.AdamOptimizer(learning_rate=self.learning_rate)
        training_op=optimizer.minimize(loss)
        correct=tf.nn.in_top_k(logits, y, 1)
        accuracy=tf.reduce_mean(tf.cast(correct, tf.float32))
        Y_prob = tf.nn.softmax(logits, name="Y_proba")
        init=tf.global_variables_initializer()
        saver = tf.train.Saver()
        # Make the important operations available easily through instance variables
        self._X, self._y = X, y
        self._loss, self.Y_prob = loss, Y_prob
        self._training_op, self._accuracy = training_op, accuracy
        self._init, self._saver = init, saver
        
    def fit(self, X_validation, y_validation):
        n_batches=len(self.data)//self.batch_size
        best_validation_loss=np.infty
        max_checks_no_progress=20
        check_without_process=0
        
        start=time.time()
        self.build_graph()
        self._session = tf.Session()
        with self._session.as_default() as sess:
            self._init.run()
            #revs, W, word_idx_map, max_sentence_len, batch_size=50, batch_index=1
            for epoch in range(self.n_epoches):
                for batch in range(1, n_batches):
                    X_batch, y_batch=embedding_batch(self.data, self.W, word_idx_map, 30, \
                                            batch_size=self.batch_size, batch_index=batch)
                    sess.run(self._training_op, feed_dict={self.is_training:True, self._X:X_batch.reshape(self.batch_size,self.n_input), self._y:y_batch.reshape(self.batch_size)})
                batch_training_accuracy=self._accuracy.eval(feed_dict={self.is_training:True, self._X:X_batch.reshape(self.batch_size,self.n_input), self._y:y_batch.reshape(self.batch_size)})
                validation_accuracy=self._accuracy.eval(feed_dict={self.is_training:False, self._X:X_validation.reshape(-1,self.n_input), self._y:y_validation.reshape(-1)})
                validation_loss=self._loss.eval(feed_dict={self.is_training:False, self._X:X_validation.reshape(-1,self.n_input), self._y:y_validation.reshape(-1)})
                print("Epoch:", epoch, "training:", batch_training_accuracy, "validation:", validation_accuracy, \
                      "valid_loss", validation_loss, "best_loss", best_validation_loss)
                if(validation_loss<best_validation_loss):
                    save_path = self._saver.save(sess, "./dnn_sentiment.ckpt")
                    best_validation_loss=validation_loss
                    check_without_process=0
                else:
                    check_without_process+=1
                    if check_without_process>=max_checks_no_progress:
                        print("Early stopping!")
                        break;
        end=time.time()
        print("Training completed in {} minutes".format((time.time()-start)/60))
        
    def predict_proba(self, X):
#         if not self._session:
#             raise NotFittedError("This %s instance is not fitted yet" % self.__class__.__name__)
        #with tf.Session() as sess:
        with self._session.as_default() as sess:
        #self._init.run()
            return self.Y_prob.eval(feed_dict={self._X: X})

    def predict(self, X):
        class_indices = np.argmax(self.predict_proba(X.reshape(-1, self.n_input)), axis=1)
        return np.array(class_indices)

# %%
# dnn_clf=My_DNN(W=word2vec, n_neurons=100, n_layers=4, learning_rate=0.01, n_epoches=300,\
#                batch_size=64, batch_norm_momentum=0.99, dropout_rate=0.5)
# dnn_clf.fit(revs)
a=np.arange(0,200).reshape(10,20)
a.reshape(-1).shape
# Out:
# (200,)

# %%
from sklearn.model_selection import GridSearchCV
import time

X_validation, y_validation=embedding_batch(valid, word2vec, word_idx_map, 30, \
                                            batch_size=5000, batch_index=0)

del valid

params = {
    "n_neurons": [100, 150, 250],
    "batch_size": [64, 128],
    "learning_rate": [0.01, 0.001],
#     "activation": [tf.nn.relu, tf.nn.elu],
    # you could also try exploring different numbers of hidden layers, different optimizers, etc.
    "n_layers": [3,5,7,9],
#     "batch_norm_momentum": [0.99, None],
#     "dropout_rate":[0.4, 0.5, 0.6, None],
    #"optimizer_class": [tf.train.AdamOptimizer, partial(tf.train.MomentumOptimizer, momentum=0.95)],
}
start=time.time()
rnd_dnn_clf=My_DNN(data=train, W=word2vec, n_epoches=500, batch_norm_momentum=0.99, dropout_rate=0.5)

rnd_search = GridSearchCV(rnd_dnn_clf, param_grid = params, scoring='f1', verbose=2)
rnd_search.fit(X_validation, y_validation)
print("*******************************************************")
print("Complete in {} minutes".format((time.time()-start)/60))
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [CV] learning_rate=0.01, n_layers=3, n_neurons=100, batch_size=64 ....
# ('Epoch:', 0, 'training:', 0.734375, 'validation:', 0.63126314, 'valid_loss', 0.67676961, 'best_loss', inf)
# ('Epoch:', 1, 'training:', 0.65625, 'validation:', 0.66336632, 'valid_loss', 0.64863241, 'best_loss', 0.67676961)
# ('Epoch:', 2, 'training:', 0.71875, 'validation:', 0.67656767, 'valid_loss', 0.63635153, 'best_loss', 0.64863241)
# ('Epoch:', 3, 'training:', 0.6875, 'validation:', 0.67626762, 'valid_loss', 0.63609034, 'best_loss', 0.63635153)
# ('Epoch:', 4, 'training:', 0.734375, 'validation:', 0.69276929, 'valid_loss', 0.61935794, 'best_loss', 0.63609034)
# ('Epoch:', 5, 'training:', 0.78125, 'validation:', 0.66726673, 'valid_loss', 0.64603835, 'best_loss', 0.61935794)
# ('Epoch:', 6, 'training:', 0.78125, 'validation:', 0.6870687, 'valid_loss', 0.62603199, 'best_loss', 0.61935794)
# ('Epoch:', 7, 'training:', 0.828125, 'validation:', 0.66666669, 'valid_loss', 0.64660186, 'best_loss', 0.61935794)
# ('Epoch:', 8, 'training:', 0.796875, 'validation:', 0.68796879, 'valid_loss', 0.62484652, 'best_loss', 0.61935794)
# ('Epoch:', 9, 'training:', 0.859375, 'validation:', 0.68076807, 'valid_loss', 0.6324988, 'best_loss', 0.61935794)
# ('Epoch:', 10, 'training:', 0.828125, 'validation:', 0.70657068, 'valid_loss', 0.60675764, 'best_loss', 0.61935794)
# ('Epoch:', 11, 'training:', 0.859375, 'validation:', 0.67866784, 'valid_loss', 0.63457263, 'best_loss', 0.60675764)
# ('Epoch:', 12, 'training:', 0.8125, 'validation:', 0.69966996, 'valid_loss', 0.61338031, 'best_loss', 0.60675764)
# ('Epoch:', 13, 'training:', 0.828125, 'validation:', 0.69456947, 'valid_loss', 0.6186983, 'best_loss', 0.60675764)
# ('Epoch:', 14, 'training:', 0.765625, 'validation:', 0.71497148, 'valid_loss', 0.59808576, 'best_loss', 0.60675764)
# ('Epoch:', 15, 'training:', 0.765625, 'validation:', 0.71227121, 'valid_loss', 0.60089743, 'best_loss', 0.59808576)
# ('Epoch:', 16, 'training:', 0.796875, 'validation:', 0.71047103, 'valid_loss', 0.60287988, 'best_loss', 0.59808576)
# ('Epoch:', 17, 'training:', 0.75, 'validation:', 0.71647167, 'valid_loss', 0.59672874, 'best_loss', 0.59808576)
# ('Epoch:', 18, 'training:', 0.875, 'validation:', 0.71677166, 'valid_loss', 0.59631741, 'best_loss', 0.59672874)
# ('Epoch:', 19, 'training:', 0.765625, 'validation:', 0.72457248, 'valid_loss', 0.58873677, 'best_loss', 0.59631741)
# ('Epoch:', 20, 'training:', 0.828125, 'validation:', 0.71287131, 'valid_loss', 0.60002267, 'best_loss', 0.58873677)
# ('Epoch:', 21, 'training:', 0.8125, 'validation:', 0.7179718, 'valid_loss', 0.59515417, 'best_loss', 0.58873677)
# ('Epoch:', 22, 'training:', 0.703125, 'validation:', 0.72307229, 'valid_loss', 0.59001118, 'best_loss', 0.58873677)
# ('Epoch:', 23, 'training:', 0.8125, 'validation:', 0.72397238, 'valid_loss', 0.58913785, 'best_loss', 0.58873677)
# ('Epoch:', 24, 'training:', 0.796875, 'validation:', 0.72487247, 'valid_loss', 0.58839035, 'best_loss', 0.58873677)
# ('Epoch:', 25, 'training:', 0.78125, 'validation:', 0.72607261, 'valid_loss', 0.58717638, 'best_loss', 0.58839035)
# ('Epoch:', 26, 'training:', 0.796875, 'validation:', 0.72187221, 'valid_loss', 0.59139055, 'best_loss', 0.58717638)
# ('Epoch:', 27, 'training:', 0.8125, 'validation:', 0.72007203, 'valid_loss', 0.59325218, 'best_loss', 0.58717638)
# ('Epoch:', 28, 'training:', 0.8125, 'validation:', 0.71827185, 'valid_loss', 0.59499568, 'best_loss', 0.58717638)
# ('Epoch:', 29, 'training:', 0.8125, 'validation:', 0.71527153, 'valid_loss', 0.59799391, 'best_loss', 0.58717638)
# ('Epoch:', 30, 'training:', 0.84375, 'validation:', 0.72367239, 'valid_loss', 0.58959061, 'best_loss', 0.58717638)
# ('Epoch:', 31, 'training:', 0.8125, 'validation:', 0.72067207, 'valid_loss', 0.59261537, 'best_loss', 0.58717638)
# ('Epoch:', 32, 'training:', 0.859375, 'validation:', 0.72037202, 'valid_loss', 0.59289569, 'best_loss', 0.58717638)
# ('Epoch:', 33, 'training:', 0.78125, 'validation:', 0.73687369, 'valid_loss', 0.57638937, 'best_loss', 0.58717638)
# ('Epoch:', 34, 'training:', 0.875, 'validation:', 0.7359736, 'valid_loss', 0.57728511, 'best_loss', 0.57638937)
# ('Epoch:', 35, 'training:', 0.828125, 'validation:', 0.7311731, 'valid_loss', 0.58215714, 'best_loss', 0.57638937)
# ('Epoch:', 36, 'training:', 0.859375, 'validation:', 0.72757274, 'valid_loss', 0.58569115, 'best_loss', 0.57638937)
# ('Epoch:', 37, 'training:', 0.78125, 'validation:', 0.73477346, 'valid_loss', 0.57839066, 'best_loss', 0.57638937)
# ('Epoch:', 38, 'training:', 0.828125, 'validation:', 0.73417342, 'valid_loss', 0.57895082, 'best_loss', 0.57638937)
# ('Epoch:', 39, 'training:', 0.8125, 'validation:', 0.73297328, 'valid_loss', 0.58023727, 'best_loss', 0.57638937)
# ('Epoch:', 40, 'training:', 0.828125, 'validation:', 0.73237324, 'valid_loss', 0.58088595, 'best_loss', 0.57638937)
# ('Epoch:', 41, 'training:', 0.8125, 'validation:', 0.73207319, 'valid_loss', 0.58118963, 'best_loss', 0.57638937)
# ('Epoch:', 42, 'training:', 0.84375, 'validation:', 0.72667265, 'valid_loss', 0.58659017, 'best_loss', 0.57638937)
# ('Epoch:', 43, 'training:', 0.8125, 'validation:', 0.72607261, 'valid_loss', 0.58719021, 'best_loss', 0.57638937)
# ('Epoch:', 44, 'training:', 0.796875, 'validation:', 0.72757274, 'valid_loss', 0.58568996, 'best_loss', 0.57638937)
# ('Epoch:', 45, 'training:', 0.921875, 'validation:', 0.73027301, 'valid_loss', 0.58298498, 'best_loss', 0.57638937)
# ('Epoch:', 46, 'training:', 0.796875, 'validation:', 0.7359736, 'valid_loss', 0.57728922, 'best_loss', 0.57638937)
# ('Epoch:', 47, 'training:', 0.84375, 'validation:', 0.72967297, 'valid_loss', 0.58358991, 'best_loss', 0.57638937)
# ('Epoch:', 48, 'training:', 0.796875, 'validation:', 0.7269727, 'valid_loss', 0.58632582, 'best_loss', 0.57638937)
# ('Epoch:', 49, 'training:', 0.734375, 'validation:', 0.72907293, 'valid_loss', 0.58417672, 'best_loss', 0.57638937)
# ('Epoch:', 50, 'training:', 0.859375, 'validation:', 0.73417342, 'valid_loss', 0.57908434, 'best_loss', 0.57638937)
# ('Epoch:', 51, 'training:', 0.84375, 'validation:', 0.74047405, 'valid_loss', 0.57278877, 'best_loss', 0.57638937)
# ('Epoch:', 52, 'training:', 0.8125, 'validation:', 0.73837382, 'valid_loss', 0.574889, 'best_loss', 0.57278877)
# ('Epoch:', 53, 'training:', 0.78125, 'validation:', 0.73447347, 'valid_loss', 0.57878935, 'best_loss', 0.57278877)
# ('Epoch:', 54, 'training:', 0.859375, 'validation:', 0.740174, 'valid_loss', 0.57313108, 'best_loss', 0.57278877)
# ('Epoch:', 55, 'training:', 0.8125, 'validation:', 0.73837382, 'valid_loss', 0.5747509, 'best_loss', 0.57278877)
# ('Epoch:', 56, 'training:', 0.78125, 'validation:', 0.73897392, 'valid_loss', 0.57428855, 'best_loss', 0.57278877)
# ('Epoch:', 57, 'training:', 0.765625, 'validation:', 0.73927391, 'valid_loss', 0.5739882, 'best_loss', 0.57278877)
# ('Epoch:', 58, 'training:', 0.875, 'validation:', 0.73267329, 'valid_loss', 0.58056718, 'best_loss', 0.57278877)
# ('Epoch:', 59, 'training:', 0.8125, 'validation:', 0.7317732, 'valid_loss', 0.58149052, 'best_loss', 0.57278877)
# ('Epoch:', 60, 'training:', 0.8125, 'validation:', 0.73657364, 'valid_loss', 0.57661849, 'best_loss', 0.57278877)
# ('Epoch:', 61, 'training:', 0.78125, 'validation:', 0.7359736, 'valid_loss', 0.57728922, 'best_loss', 0.57278877)
# ('Epoch:', 62, 'training:', 0.859375, 'validation:', 0.73297328, 'valid_loss', 0.58017677, 'best_loss', 0.57278877)
# ('Epoch:', 63, 'training:', 0.84375, 'validation:', 0.74257427, 'valid_loss', 0.57050318, 'best_loss', 0.57278877)
# ('Epoch:', 64, 'training:', 0.8125, 'validation:', 0.72937292, 'valid_loss', 0.58382165, 'best_loss', 0.57050318)
# ('Epoch:', 65, 'training:', 0.84375, 'validation:', 0.7317732, 'valid_loss', 0.58148891, 'best_loss', 0.57050318)
# ('Epoch:', 66, 'training:', 0.75, 'validation:', 0.73657364, 'valid_loss', 0.57668918, 'best_loss', 0.57050318)
# ('Epoch:', 67, 'training:', 0.828125, 'validation:', 0.73867387, 'valid_loss', 0.57451862, 'best_loss', 0.57050318)
# ('Epoch:', 68, 'training:', 0.796875, 'validation:', 0.73207319, 'valid_loss', 0.58118337, 'best_loss', 0.57050318)
# ('Epoch:', 69, 'training:', 0.75, 'validation:', 0.73357338, 'valid_loss', 0.57968897, 'best_loss', 0.57050318)
# ('Epoch:', 70, 'training:', 0.8125, 'validation:', 0.73717374, 'valid_loss', 0.57608908, 'best_loss', 0.57050318)
# ('Epoch:', 71, 'training:', 0.828125, 'validation:', 0.72757274, 'valid_loss', 0.58568579, 'best_loss', 0.57050318)
# ('Epoch:', 72, 'training:', 0.828125, 'validation:', 0.73537356, 'valid_loss', 0.57788932, 'best_loss', 0.57050318)
# ('Epoch:', 73, 'training:', 0.828125, 'validation:', 0.72427243, 'valid_loss', 0.58892149, 'best_loss', 0.57050318)
# ('Epoch:', 74, 'training:', 0.875, 'validation:', 0.72997302, 'valid_loss', 0.5832898, 'best_loss', 0.57050318)
# ('Epoch:', 75, 'training:', 0.859375, 'validation:', 0.72607261, 'valid_loss', 0.58719027, 'best_loss', 0.57050318)
# ('Epoch:', 76, 'training:', 0.90625, 'validation:', 0.73087311, 'valid_loss', 0.58238971, 'best_loss', 0.57050318)
# ('Epoch:', 77, 'training:', 0.734375, 'validation:', 0.72817284, 'valid_loss', 0.5850895, 'best_loss', 0.57050318)
# ('Epoch:', 78, 'training:', 0.921875, 'validation:', 0.72787279, 'valid_loss', 0.58546072, 'best_loss', 0.57050318)
# ('Epoch:', 79, 'training:', 0.78125, 'validation:', 0.73327333, 'valid_loss', 0.57998949, 'best_loss', 0.57050318)
# ('Epoch:', 80, 'training:', 0.828125, 'validation:', 0.73267329, 'valid_loss', 0.58067238, 'best_loss', 0.57050318)
# ('Epoch:', 81, 'training:', 0.84375, 'validation:', 0.72997302, 'valid_loss', 0.5832898, 'best_loss', 0.57050318)
# ('Epoch:', 82, 'training:', 0.734375, 'validation:', 0.72967297, 'valid_loss', 0.58358121, 'best_loss', 0.57050318)
# ('Epoch:', 83, 'training:', 0.734375, 'validation:', 0.73627365, 'valid_loss', 0.57698089, 'best_loss', 0.57050318)
# Early stopping!
# Training completed in 60.2611477852 minutes
# [CV]  learning_rate=0.01, n_layers=3, n_neurons=100, batch_size=64, total=60.3min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 60.3min remaining:    0.0s
# [CV] learning_rate=0.01, n_layers=3, n_neurons=100, batch_size=64 ....
# ('Epoch:', 0, 'training:', 0.640625, 'validation:', 0.65346533, 'valid_loss', 0.65339291, 'best_loss', inf)
# ('Epoch:', 1, 'training:', 0.78125, 'validation:', 0.64146417, 'valid_loss', 0.66925889, 'best_loss', 0.65339291)
# ('Epoch:', 2, 'training:', 0.71875, 'validation:', 0.65166515, 'valid_loss', 0.66142589, 'best_loss', 0.65339291)
# ('Epoch:', 3, 'training:', 0.734375, 'validation:', 0.66216624, 'valid_loss', 0.65095192, 'best_loss', 0.65339291)
# ('Epoch:', 4, 'training:', 0.6875, 'validation:', 0.68976897, 'valid_loss', 0.62278867, 'best_loss', 0.65095192)
# ('Epoch:', 5, 'training:', 0.71875, 'validation:', 0.69216919, 'valid_loss', 0.62146169, 'best_loss', 0.62278867)
# ('Epoch:', 6, 'training:', 0.71875, 'validation:', 0.68526852, 'valid_loss', 0.6275757, 'best_loss', 0.62146169)
# ('Epoch:', 7, 'training:', 0.78125, 'validation:', 0.68586856, 'valid_loss', 0.62710583, 'best_loss', 0.62146169)
# ('Epoch:', 8, 'training:', 0.6875, 'validation:', 0.70417041, 'valid_loss', 0.60842764, 'best_loss', 0.62146169)
# ('Epoch:', 9, 'training:', 0.703125, 'validation:', 0.71047103, 'valid_loss', 0.60254061, 'best_loss', 0.60842764)
# ('Epoch:', 10, 'training:', 0.6875, 'validation:', 0.71437144, 'valid_loss', 0.59890407, 'best_loss', 0.60254061)
# ('Epoch:', 11, 'training:', 0.78125, 'validation:', 0.71137112, 'valid_loss', 0.6012429, 'best_loss', 0.59890407)
# ('Epoch:', 12, 'training:', 0.71875, 'validation:', 0.71587157, 'valid_loss', 0.59720665, 'best_loss', 0.59890407)
# ('Epoch:', 13, 'training:', 0.640625, 'validation:', 0.72457248, 'valid_loss', 0.58859223, 'best_loss', 0.59720665)
# ('Epoch:', 14, 'training:', 0.78125, 'validation:', 0.71887189, 'valid_loss', 0.59428585, 'best_loss', 0.58859223)
# ('Epoch:', 15, 'training:', 0.734375, 'validation:', 0.72127211, 'valid_loss', 0.59181213, 'best_loss', 0.58859223)
# ('Epoch:', 16, 'training:', 0.734375, 'validation:', 0.7317732, 'valid_loss', 0.58135027, 'best_loss', 0.58859223)
# ('Epoch:', 17, 'training:', 0.796875, 'validation:', 0.71647167, 'valid_loss', 0.59676534, 'best_loss', 0.58135027)
# ('Epoch:', 18, 'training:', 0.703125, 'validation:', 0.73327333, 'valid_loss', 0.58005685, 'best_loss', 0.58135027)
# ('Epoch:', 19, 'training:', 0.765625, 'validation:', 0.7311731, 'valid_loss', 0.58218169, 'best_loss', 0.58005685)
# ('Epoch:', 20, 'training:', 0.78125, 'validation:', 0.72397238, 'valid_loss', 0.58928466, 'best_loss', 0.58005685)
# ('Epoch:', 21, 'training:', 0.78125, 'validation:', 0.73957396, 'valid_loss', 0.57357854, 'best_loss', 0.58005685)
# ('Epoch:', 22, 'training:', 0.8125, 'validation:', 0.73387337, 'valid_loss', 0.57938677, 'best_loss', 0.57357854)
# ('Epoch:', 23, 'training:', 0.78125, 'validation:', 0.72457248, 'valid_loss', 0.58859164, 'best_loss', 0.57357854)
# ('Epoch:', 24, 'training:', 0.796875, 'validation:', 0.72757274, 'valid_loss', 0.58564276, 'best_loss', 0.57357854)
# ('Epoch:', 25, 'training:', 0.796875, 'validation:', 0.72907293, 'valid_loss', 0.58420807, 'best_loss', 0.57357854)
# ('Epoch:', 26, 'training:', 0.75, 'validation:', 0.74167418, 'valid_loss', 0.57164568, 'best_loss', 0.57357854)
# ('Epoch:', 27, 'training:', 0.828125, 'validation:', 0.73387337, 'valid_loss', 0.57944357, 'best_loss', 0.57164568)
# ('Epoch:', 28, 'training:', 0.765625, 'validation:', 0.74377435, 'valid_loss', 0.56958348, 'best_loss', 0.57164568)
# ('Epoch:', 29, 'training:', 0.8125, 'validation:', 0.73717374, 'valid_loss', 0.57608801, 'best_loss', 0.56958348)
# ('Epoch:', 30, 'training:', 0.71875, 'validation:', 0.74227422, 'valid_loss', 0.57097977, 'best_loss', 0.56958348)
# ('Epoch:', 31, 'training:', 0.8125, 'validation:', 0.74197417, 'valid_loss', 0.57120246, 'best_loss', 0.56958348)
# ('Epoch:', 32, 'training:', 0.765625, 'validation:', 0.74137414, 'valid_loss', 0.57188565, 'best_loss', 0.56958348)
# ('Epoch:', 33, 'training:', 0.8125, 'validation:', 0.73477346, 'valid_loss', 0.57848829, 'best_loss', 0.56958348)
# ('Epoch:', 34, 'training:', 0.78125, 'validation:', 0.73657364, 'valid_loss', 0.57655257, 'best_loss', 0.56958348)
# ('Epoch:', 35, 'training:', 0.84375, 'validation:', 0.7317732, 'valid_loss', 0.58148962, 'best_loss', 0.56958348)
# ('Epoch:', 36, 'training:', 0.78125, 'validation:', 0.74677467, 'valid_loss', 0.56651533, 'best_loss', 0.56958348)
# ('Epoch:', 37, 'training:', 0.796875, 'validation:', 0.74197417, 'valid_loss', 0.57128865, 'best_loss', 0.56651533)
# ('Epoch:', 38, 'training:', 0.75, 'validation:', 0.74347436, 'valid_loss', 0.56975055, 'best_loss', 0.56651533)
# ('Epoch:', 39, 'training:', 0.765625, 'validation:', 0.74557453, 'valid_loss', 0.56768823, 'best_loss', 0.56651533)
# ('Epoch:', 40, 'training:', 0.78125, 'validation:', 0.73357338, 'valid_loss', 0.57950997, 'best_loss', 0.56651533)
# ('Epoch:', 41, 'training:', 0.78125, 'validation:', 0.74947494, 'valid_loss', 0.56380183, 'best_loss', 0.56651533)
# ('Epoch:', 42, 'training:', 0.84375, 'validation:', 0.73237324, 'valid_loss', 0.58097929, 'best_loss', 0.56380183)
# ('Epoch:', 43, 'training:', 0.796875, 'validation:', 0.73897392, 'valid_loss', 0.57436174, 'best_loss', 0.56380183)
# ('Epoch:', 44, 'training:', 0.78125, 'validation:', 0.7440744, 'valid_loss', 0.56918842, 'best_loss', 0.56380183)
# ('Epoch:', 45, 'training:', 0.796875, 'validation:', 0.74197417, 'valid_loss', 0.57132298, 'best_loss', 0.56380183)
# ('Epoch:', 46, 'training:', 0.828125, 'validation:', 0.73327333, 'valid_loss', 0.57999778, 'best_loss', 0.56380183)
# ('Epoch:', 47, 'training:', 0.765625, 'validation:', 0.74317431, 'valid_loss', 0.56999701, 'best_loss', 0.56380183)
# ('Epoch:', 48, 'training:', 0.765625, 'validation:', 0.73987401, 'valid_loss', 0.57329816, 'best_loss', 0.56380183)
# ('Epoch:', 49, 'training:', 0.765625, 'validation:', 0.74317431, 'valid_loss', 0.57008851, 'best_loss', 0.56380183)
# ('Epoch:', 50, 'training:', 0.765625, 'validation:', 0.74857485, 'valid_loss', 0.56466126, 'best_loss', 0.56380183)
# ('Epoch:', 51, 'training:', 0.796875, 'validation:', 0.74467444, 'valid_loss', 0.56849384, 'best_loss', 0.56380183)
# ('Epoch:', 52, 'training:', 0.8125, 'validation:', 0.7482748, 'valid_loss', 0.56486237, 'best_loss', 0.56380183)
# ('Epoch:', 53, 'training:', 0.6875, 'validation:', 0.74287426, 'valid_loss', 0.57038856, 'best_loss', 0.56380183)
# ('Epoch:', 54, 'training:', 0.8125, 'validation:', 0.73507351, 'valid_loss', 0.57818925, 'best_loss', 0.56380183)
# ('Epoch:', 55, 'training:', 0.796875, 'validation:', 0.73927391, 'valid_loss', 0.57405978, 'best_loss', 0.56380183)
# ('Epoch:', 56, 'training:', 0.78125, 'validation:', 0.7440744, 'valid_loss', 0.56921554, 'best_loss', 0.56380183)
# ('Epoch:', 57, 'training:', 0.75, 'validation:', 0.74557453, 'valid_loss', 0.56768769, 'best_loss', 0.56380183)
# ('Epoch:', 58, 'training:', 0.84375, 'validation:', 0.75097507, 'valid_loss', 0.56228775, 'best_loss', 0.56380183)
# ('Epoch:', 59, 'training:', 0.796875, 'validation:', 0.75037503, 'valid_loss', 0.56289506, 'best_loss', 0.56228775)
# ('Epoch:', 60, 'training:', 0.84375, 'validation:', 0.74677467, 'valid_loss', 0.56637418, 'best_loss', 0.56228775)
# ('Epoch:', 61, 'training:', 0.765625, 'validation:', 0.75427544, 'valid_loss', 0.55898738, 'best_loss', 0.56228775)
# ('Epoch:', 62, 'training:', 0.8125, 'validation:', 0.74977499, 'valid_loss', 0.56348765, 'best_loss', 0.55898738)
# ('Epoch:', 63, 'training:', 0.78125, 'validation:', 0.74947494, 'valid_loss', 0.56378734, 'best_loss', 0.55898738)
# ('Epoch:', 64, 'training:', 0.84375, 'validation:', 0.74347436, 'valid_loss', 0.56978846, 'best_loss', 0.55898738)
# ('Epoch:', 65, 'training:', 0.859375, 'validation:', 0.74437445, 'valid_loss', 0.56888837, 'best_loss', 0.55898738)
# ('Epoch:', 66, 'training:', 0.8125, 'validation:', 0.73777378, 'valid_loss', 0.57548904, 'best_loss', 0.55898738)
# ('Epoch:', 67, 'training:', 0.78125, 'validation:', 0.74107409, 'valid_loss', 0.57218874, 'best_loss', 0.55898738)
# ('Epoch:', 68, 'training:', 0.765625, 'validation:', 0.74227422, 'valid_loss', 0.5709886, 'best_loss', 0.55898738)
# ('Epoch:', 69, 'training:', 0.75, 'validation:', 0.75067508, 'valid_loss', 0.56269443, 'best_loss', 0.55898738)
# ('Epoch:', 70, 'training:', 0.8125, 'validation:', 0.74947494, 'valid_loss', 0.56378788, 'best_loss', 0.55898738)
# ('Epoch:', 71, 'training:', 0.78125, 'validation:', 0.74797481, 'valid_loss', 0.56528801, 'best_loss', 0.55898738)
# ('Epoch:', 72, 'training:', 0.875, 'validation:', 0.74617463, 'valid_loss', 0.56688595, 'best_loss', 0.55898738)
# ('Epoch:', 73, 'training:', 0.796875, 'validation:', 0.74347436, 'valid_loss', 0.56977868, 'best_loss', 0.55898738)
# ('Epoch:', 74, 'training:', 0.734375, 'validation:', 0.75277525, 'valid_loss', 0.56048417, 'best_loss', 0.55898738)
# ('Epoch:', 75, 'training:', 0.8125, 'validation:', 0.74617463, 'valid_loss', 0.56700277, 'best_loss', 0.55898738)
# ('Epoch:', 76, 'training:', 0.8125, 'validation:', 0.74947494, 'valid_loss', 0.56378782, 'best_loss', 0.55898738)
# ('Epoch:', 77, 'training:', 0.875, 'validation:', 0.75097507, 'valid_loss', 0.56228781, 'best_loss', 0.55898738)
# ('Epoch:', 78, 'training:', 0.828125, 'validation:', 0.75337535, 'valid_loss', 0.55988753, 'best_loss', 0.55898738)
# ('Epoch:', 79, 'training:', 0.8125, 'validation:', 0.75697571, 'valid_loss', 0.55636013, 'best_loss', 0.55898738)
# ('Epoch:', 80, 'training:', 0.828125, 'validation:', 0.75817579, 'valid_loss', 0.55507046, 'best_loss', 0.55636013)
# ('Epoch:', 81, 'training:', 0.75, 'validation:', 0.75817579, 'valid_loss', 0.55508685, 'best_loss', 0.55507046)
# ('Epoch:', 82, 'training:', 0.8125, 'validation:', 0.75847584, 'valid_loss', 0.55477506, 'best_loss', 0.55507046)
# ('Epoch:', 83, 'training:', 0.828125, 'validation:', 0.7482748, 'valid_loss', 0.56498802, 'best_loss', 0.55477506)
# ('Epoch:', 84, 'training:', 0.78125, 'validation:', 0.75187516, 'valid_loss', 0.56147581, 'best_loss', 0.55477506)
# ('Epoch:', 85, 'training:', 0.796875, 'validation:', 0.74857485, 'valid_loss', 0.56468797, 'best_loss', 0.55477506)
# ('Epoch:', 86, 'training:', 0.875, 'validation:', 0.75667566, 'valid_loss', 0.55658734, 'best_loss', 0.55477506)
# ('Epoch:', 87, 'training:', 0.703125, 'validation:', 0.75067508, 'valid_loss', 0.56241512, 'best_loss', 0.55477506)
# ('Epoch:', 88, 'training:', 0.859375, 'validation:', 0.75637561, 'valid_loss', 0.55685705, 'best_loss', 0.55477506)
# ('Epoch:', 89, 'training:', 0.78125, 'validation:', 0.76087606, 'valid_loss', 0.552387, 'best_loss', 0.55477506)
# ('Epoch:', 90, 'training:', 0.703125, 'validation:', 0.75067508, 'valid_loss', 0.56258774, 'best_loss', 0.552387)
# ('Epoch:', 91, 'training:', 0.828125, 'validation:', 0.75397539, 'valid_loss', 0.55928707, 'best_loss', 0.552387)
# ('Epoch:', 92, 'training:', 0.78125, 'validation:', 0.75217521, 'valid_loss', 0.56108761, 'best_loss', 0.552387)
# ('Epoch:', 93, 'training:', 0.796875, 'validation:', 0.74137414, 'valid_loss', 0.57191658, 'best_loss', 0.552387)
# ('Epoch:', 94, 'training:', 0.828125, 'validation:', 0.7572757, 'valid_loss', 0.55609244, 'best_loss', 0.552387)
# ('Epoch:', 95, 'training:', 0.84375, 'validation:', 0.74557453, 'valid_loss', 0.56768829, 'best_loss', 0.552387)
# ('Epoch:', 96, 'training:', 0.796875, 'validation:', 0.74947494, 'valid_loss', 0.56378788, 'best_loss', 0.552387)
# ('Epoch:', 97, 'training:', 0.78125, 'validation:', 0.74797481, 'valid_loss', 0.56528801, 'best_loss', 0.552387)
# ('Epoch:', 98, 'training:', 0.84375, 'validation:', 0.74977499, 'valid_loss', 0.56348783, 'best_loss', 0.552387)
# ('Epoch:', 99, 'training:', 0.859375, 'validation:', 0.75007498, 'valid_loss', 0.56318784, 'best_loss', 0.552387)
# ('Epoch:', 100, 'training:', 0.765625, 'validation:', 0.74047405, 'valid_loss', 0.57279205, 'best_loss', 0.552387)
# ('Epoch:', 101, 'training:', 0.890625, 'validation:', 0.74437445, 'valid_loss', 0.56888837, 'best_loss', 0.552387)
# ('Epoch:', 102, 'training:', 0.828125, 'validation:', 0.73147315, 'valid_loss', 0.58178538, 'best_loss', 0.552387)
# ('Epoch:', 103, 'training:', 0.890625, 'validation:', 0.74467444, 'valid_loss', 0.56858838, 'best_loss', 0.552387)
# ('Epoch:', 104, 'training:', 0.78125, 'validation:', 0.75217521, 'valid_loss', 0.56108743, 'best_loss', 0.552387)
# ('Epoch:', 105, 'training:', 0.828125, 'validation:', 0.75097507, 'valid_loss', 0.56228775, 'best_loss', 0.552387)
# ('Epoch:', 106, 'training:', 0.8125, 'validation:', 0.74557453, 'valid_loss', 0.56768829, 'best_loss', 0.552387)
# ('Epoch:', 107, 'training:', 0.8125, 'validation:', 0.74347436, 'valid_loss', 0.56974554, 'best_loss', 0.552387)
# ('Epoch:', 108, 'training:', 0.859375, 'validation:', 0.74737471, 'valid_loss', 0.56588817, 'best_loss', 0.552387)
# ('Epoch:', 109, 'training:', 0.875, 'validation:', 0.74977499, 'valid_loss', 0.56348783, 'best_loss', 0.552387)
# Early stopping!
# Training completed in 75.9260395169 minutes
# [CV]  learning_rate=0.01, n_layers=3, n_neurons=100, batch_size=64, total=75.9min
# [CV] learning_rate=0.01, n_layers=3, n_neurons=100, batch_size=64 ....
# ('Epoch:', 0, 'training:', 0.734375, 'validation:', 0.64547092, 'valid_loss', 0.66332507, 'best_loss', inf)
# ('Epoch:', 1, 'training:', 0.71875, 'validation:', 0.67606479, 'valid_loss', 0.63615769, 'best_loss', 0.66332507)
# ('Epoch:', 2, 'training:', 0.703125, 'validation:', 0.70335931, 'valid_loss', 0.60949129, 'best_loss', 0.63615769)
# ('Epoch:', 3, 'training:', 0.765625, 'validation:', 0.68536294, 'valid_loss', 0.62701404, 'best_loss', 0.60949129)
# ('Epoch:', 4, 'training:', 0.78125, 'validation:', 0.69946009, 'valid_loss', 0.61401278, 'best_loss', 0.60949129)
# ('Epoch:', 5, 'training:', 0.78125, 'validation:', 0.71565688, 'valid_loss', 0.59689987, 'best_loss', 0.60949129)
# ('Epoch:', 6, 'training:', 0.78125, 'validation:', 0.72465509, 'valid_loss', 0.58872592, 'best_loss', 0.59689987)
# ('Epoch:', 7, 'training:', 0.8125, 'validation:', 0.72525495, 'valid_loss', 0.58801371, 'best_loss', 0.58872592)
# ('Epoch:', 8, 'training:', 0.703125, 'validation:', 0.71655667, 'valid_loss', 0.59620422, 'best_loss', 0.58801371)
# ('Epoch:', 9, 'training:', 0.703125, 'validation:', 0.73365325, 'valid_loss', 0.57943529, 'best_loss', 0.58801371)
# ('Epoch:', 10, 'training:', 0.71875, 'validation:', 0.72885424, 'valid_loss', 0.58420849, 'best_loss', 0.57943529)
# ('Epoch:', 11, 'training:', 0.6875, 'validation:', 0.72735453, 'valid_loss', 0.58569336, 'best_loss', 0.57943529)
# ('Epoch:', 12, 'training:', 0.84375, 'validation:', 0.73005396, 'valid_loss', 0.58309919, 'best_loss', 0.57943529)
# ('Epoch:', 13, 'training:', 0.75, 'validation:', 0.73485303, 'valid_loss', 0.57836157, 'best_loss', 0.57943529)
# ('Epoch:', 14, 'training:', 0.8125, 'validation:', 0.73215359, 'valid_loss', 0.58100587, 'best_loss', 0.57836157)
# ('Epoch:', 15, 'training:', 0.765625, 'validation:', 0.7396521, 'valid_loss', 0.57345861, 'best_loss', 0.57836157)
# ('Epoch:', 16, 'training:', 0.75, 'validation:', 0.74775046, 'valid_loss', 0.5655421, 'best_loss', 0.57345861)
# ('Epoch:', 17, 'training:', 0.765625, 'validation:', 0.74235153, 'valid_loss', 0.57094949, 'best_loss', 0.5655421)
# ('Epoch:', 18, 'training:', 0.78125, 'validation:', 0.74175167, 'valid_loss', 0.57152188, 'best_loss', 0.5655421)
# ('Epoch:', 19, 'training:', 0.8125, 'validation:', 0.73785245, 'valid_loss', 0.57537085, 'best_loss', 0.5655421)
# ('Epoch:', 20, 'training:', 0.75, 'validation:', 0.74535096, 'valid_loss', 0.56766295, 'best_loss', 0.5655421)
# ('Epoch:', 21, 'training:', 0.84375, 'validation:', 0.74415118, 'valid_loss', 0.56912154, 'best_loss', 0.5655421)
# ('Epoch:', 22, 'training:', 0.875, 'validation:', 0.74175167, 'valid_loss', 0.5713681, 'best_loss', 0.5655421)
# ('Epoch:', 23, 'training:', 0.765625, 'validation:', 0.74415118, 'valid_loss', 0.56908935, 'best_loss', 0.5655421)
# ('Epoch:', 24, 'training:', 0.828125, 'validation:', 0.74145168, 'valid_loss', 0.57164758, 'best_loss', 0.5655421)
# ('Epoch:', 25, 'training:', 0.765625, 'validation:', 0.74175167, 'valid_loss', 0.5715493, 'best_loss', 0.5655421)
# ('Epoch:', 26, 'training:', 0.75, 'validation:', 0.7495501, 'valid_loss', 0.56311661, 'best_loss', 0.5655421)
# ('Epoch:', 27, 'training:', 0.734375, 'validation:', 0.75194961, 'valid_loss', 0.56145895, 'best_loss', 0.56311661)
# ('Epoch:', 28, 'training:', 0.84375, 'validation:', 0.74805039, 'valid_loss', 0.56519777, 'best_loss', 0.56145895)
# ('Epoch:', 29, 'training:', 0.78125, 'validation:', 0.74805039, 'valid_loss', 0.56530493, 'best_loss', 0.56145895)
# ('Epoch:', 30, 'training:', 0.8125, 'validation:', 0.74475104, 'valid_loss', 0.56829637, 'best_loss', 0.56145895)
# ('Epoch:', 31, 'training:', 0.78125, 'validation:', 0.74355131, 'valid_loss', 0.56971151, 'best_loss', 0.56145895)
# ('Epoch:', 32, 'training:', 0.765625, 'validation:', 0.74565089, 'valid_loss', 0.56761217, 'best_loss', 0.56145895)
# ('Epoch:', 33, 'training:', 0.765625, 'validation:', 0.74475104, 'valid_loss', 0.56844676, 'best_loss', 0.56145895)
# ('Epoch:', 34, 'training:', 0.859375, 'validation:', 0.74775046, 'valid_loss', 0.56552613, 'best_loss', 0.56145895)
# ('Epoch:', 35, 'training:', 0.796875, 'validation:', 0.73935211, 'valid_loss', 0.57392704, 'best_loss', 0.56145895)
# ('Epoch:', 36, 'training:', 0.703125, 'validation:', 0.74895018, 'valid_loss', 0.56431228, 'best_loss', 0.56145895)
# ('Epoch:', 37, 'training:', 0.875, 'validation:', 0.74325132, 'valid_loss', 0.56982404, 'best_loss', 0.56145895)
# ('Epoch:', 38, 'training:', 0.8125, 'validation:', 0.74895018, 'valid_loss', 0.56431252, 'best_loss', 0.56145895)
# ('Epoch:', 39, 'training:', 0.75, 'validation:', 0.75074983, 'valid_loss', 0.56226897, 'best_loss', 0.56145895)
# ('Epoch:', 40, 'training:', 0.828125, 'validation:', 0.74715054, 'valid_loss', 0.56613886, 'best_loss', 0.56145895)
# ('Epoch:', 41, 'training:', 0.828125, 'validation:', 0.75104982, 'valid_loss', 0.56216741, 'best_loss', 0.56145895)
# ('Epoch:', 42, 'training:', 0.84375, 'validation:', 0.74745053, 'valid_loss', 0.56581986, 'best_loss', 0.56145895)
# ('Epoch:', 43, 'training:', 0.796875, 'validation:', 0.75554889, 'valid_loss', 0.55753505, 'best_loss', 0.56145895)
# ('Epoch:', 44, 'training:', 0.75, 'validation:', 0.75644869, 'valid_loss', 0.55681425, 'best_loss', 0.55753505)
# ('Epoch:', 45, 'training:', 0.828125, 'validation:', 0.75854832, 'valid_loss', 0.55483156, 'best_loss', 0.55681425)
# ('Epoch:', 46, 'training:', 0.84375, 'validation:', 0.75194961, 'valid_loss', 0.56131321, 'best_loss', 0.55483156)
# ('Epoch:', 47, 'training:', 0.796875, 'validation:', 0.75674868, 'valid_loss', 0.55657387, 'best_loss', 0.55483156)
# ('Epoch:', 48, 'training:', 0.75, 'validation:', 0.75494903, 'valid_loss', 0.5583213, 'best_loss', 0.55483156)
# ('Epoch:', 49, 'training:', 0.8125, 'validation:', 0.75494903, 'valid_loss', 0.55832535, 'best_loss', 0.55483156)
# ('Epoch:', 50, 'training:', 0.78125, 'validation:', 0.75674868, 'valid_loss', 0.55640221, 'best_loss', 0.55483156)
# ('Epoch:', 51, 'training:', 0.75, 'validation:', 0.75704861, 'valid_loss', 0.55621457, 'best_loss', 0.55483156)
# ('Epoch:', 52, 'training:', 0.765625, 'validation:', 0.75944811, 'valid_loss', 0.55381465, 'best_loss', 0.55483156)
# ('Epoch:', 53, 'training:', 0.765625, 'validation:', 0.75134975, 'valid_loss', 0.56191552, 'best_loss', 0.55381465)
# ('Epoch:', 54, 'training:', 0.84375, 'validation:', 0.74895018, 'valid_loss', 0.56428528, 'best_loss', 0.55381465)
# ('Epoch:', 55, 'training:', 0.8125, 'validation:', 0.75254947, 'valid_loss', 0.56076384, 'best_loss', 0.55381465)
# ('Epoch:', 56, 'training:', 0.875, 'validation:', 0.75254947, 'valid_loss', 0.56071949, 'best_loss', 0.55381465)
# ('Epoch:', 57, 'training:', 0.84375, 'validation:', 0.75464904, 'valid_loss', 0.55861372, 'best_loss', 0.55381465)
# ('Epoch:', 58, 'training:', 0.84375, 'validation:', 0.75524896, 'valid_loss', 0.55801386, 'best_loss', 0.55381465)
# ('Epoch:', 59, 'training:', 0.875, 'validation:', 0.75014997, 'valid_loss', 0.56310201, 'best_loss', 0.55381465)
# ('Epoch:', 60, 'training:', 0.71875, 'validation:', 0.74565089, 'valid_loss', 0.56761193, 'best_loss', 0.55381465)
# ('Epoch:', 61, 'training:', 0.796875, 'validation:', 0.7504499, 'valid_loss', 0.56281292, 'best_loss', 0.55381465)
# ('Epoch:', 62, 'training:', 0.859375, 'validation:', 0.75194961, 'valid_loss', 0.56130445, 'best_loss', 0.55381465)
# ('Epoch:', 63, 'training:', 0.8125, 'validation:', 0.75254947, 'valid_loss', 0.56075251, 'best_loss', 0.55381465)
# ('Epoch:', 64, 'training:', 0.796875, 'validation:', 0.74805039, 'valid_loss', 0.56521243, 'best_loss', 0.55381465)
# ('Epoch:', 65, 'training:', 0.78125, 'validation:', 0.75674868, 'valid_loss', 0.55651438, 'best_loss', 0.55381465)
# ('Epoch:', 66, 'training:', 0.828125, 'validation:', 0.75404918, 'valid_loss', 0.55921358, 'best_loss', 0.55381465)
# ('Epoch:', 67, 'training:', 0.765625, 'validation:', 0.75134975, 'valid_loss', 0.56191307, 'best_loss', 0.55381465)
# ('Epoch:', 68, 'training:', 0.859375, 'validation:', 0.75014997, 'valid_loss', 0.56310946, 'best_loss', 0.55381465)
# ('Epoch:', 69, 'training:', 0.8125, 'validation:', 0.75674868, 'valid_loss', 0.55651414, 'best_loss', 0.55381465)
# ('Epoch:', 70, 'training:', 0.765625, 'validation:', 0.7504499, 'valid_loss', 0.56272942, 'best_loss', 0.55381465)
# ('Epoch:', 71, 'training:', 0.796875, 'validation:', 0.74505097, 'valid_loss', 0.56832504, 'best_loss', 0.55381465)
# ('Epoch:', 72, 'training:', 0.84375, 'validation:', 0.74895018, 'valid_loss', 0.56431264, 'best_loss', 0.55381465)
# Early stopping!
# Training completed in 51.2453132192 minutes
# [CV]  learning_rate=0.01, n_layers=3, n_neurons=100, batch_size=64, total=51.2min
# [CV] learning_rate=0.01, n_layers=3, n_neurons=150, batch_size=64 ....
# ('Epoch:', 0, 'training:', 0.65625, 'validation:', 0.60216022, 'valid_loss', 0.70867944, 'best_loss', inf)
# ('Epoch:', 1, 'training:', 0.71875, 'validation:', 0.64896488, 'valid_loss', 0.66360754, 'best_loss', 0.70867944)
# ('Epoch:', 2, 'training:', 0.75, 'validation:', 0.63216323, 'valid_loss', 0.6809274, 'best_loss', 0.66360754)
# ('Epoch:', 3, 'training:', 0.734375, 'validation:', 0.63516355, 'valid_loss', 0.67809337, 'best_loss', 0.66360754)
# ('Epoch:', 4, 'training:', 0.734375, 'validation:', 0.67596757, 'valid_loss', 0.63704246, 'best_loss', 0.66360754)
# ('Epoch:', 5, 'training:', 0.71875, 'validation:', 0.66636664, 'valid_loss', 0.64668763, 'best_loss', 0.63704246)
# ('Epoch:', 6, 'training:', 0.765625, 'validation:', 0.68976897, 'valid_loss', 0.62346953, 'best_loss', 0.63704246)
# ('Epoch:', 7, 'training:', 0.84375, 'validation:', 0.66216624, 'valid_loss', 0.65074444, 'best_loss', 0.62346953)
# ('Epoch:', 8, 'training:', 0.8125, 'validation:', 0.68976897, 'valid_loss', 0.62337637, 'best_loss', 0.62346953)
# ('Epoch:', 9, 'training:', 0.703125, 'validation:', 0.69486946, 'valid_loss', 0.6185267, 'best_loss', 0.62337637)
# ('Epoch:', 10, 'training:', 0.71875, 'validation:', 0.68526852, 'valid_loss', 0.62777317, 'best_loss', 0.6185267)
# ('Epoch:', 11, 'training:', 0.796875, 'validation:', 0.70027006, 'valid_loss', 0.61273479, 'best_loss', 0.6185267)
# ('Epoch:', 12, 'training:', 0.765625, 'validation:', 0.69366938, 'valid_loss', 0.61958897, 'best_loss', 0.61273479)
# ('Epoch:', 13, 'training:', 0.71875, 'validation:', 0.6780678, 'valid_loss', 0.63519686, 'best_loss', 0.61273479)
# ('Epoch:', 14, 'training:', 0.859375, 'validation:', 0.69906992, 'valid_loss', 0.61413854, 'best_loss', 0.61273479)
# ('Epoch:', 15, 'training:', 0.734375, 'validation:', 0.69726974, 'valid_loss', 0.61596644, 'best_loss', 0.61273479)
# ('Epoch:', 16, 'training:', 0.828125, 'validation:', 0.68496847, 'valid_loss', 0.62835616, 'best_loss', 0.61273479)
# ('Epoch:', 17, 'training:', 0.859375, 'validation:', 0.71647167, 'valid_loss', 0.59677029, 'best_loss', 0.61273479)
# ('Epoch:', 18, 'training:', 0.75, 'validation:', 0.70237023, 'valid_loss', 0.61089551, 'best_loss', 0.59677029)
# ('Epoch:', 19, 'training:', 0.71875, 'validation:', 0.70297033, 'valid_loss', 0.61026937, 'best_loss', 0.59677029)
# ('Epoch:', 20, 'training:', 0.765625, 'validation:', 0.68796879, 'valid_loss', 0.62534833, 'best_loss', 0.59677029)
# ('Epoch:', 21, 'training:', 0.765625, 'validation:', 0.71527153, 'valid_loss', 0.59786779, 'best_loss', 0.59677029)
# ('Epoch:', 22, 'training:', 0.796875, 'validation:', 0.70267028, 'valid_loss', 0.61055326, 'best_loss', 0.59677029)
# ('Epoch:', 23, 'training:', 0.828125, 'validation:', 0.71917194, 'valid_loss', 0.59415317, 'best_loss', 0.59677029)
# ('Epoch:', 24, 'training:', 0.78125, 'validation:', 0.70747077, 'valid_loss', 0.60578352, 'best_loss', 0.59415317)
# ('Epoch:', 25, 'training:', 0.84375, 'validation:', 0.69786978, 'valid_loss', 0.61539179, 'best_loss', 0.59415317)
# ('Epoch:', 26, 'training:', 0.78125, 'validation:', 0.7131713, 'valid_loss', 0.60009062, 'best_loss', 0.59415317)
# ('Epoch:', 27, 'training:', 0.765625, 'validation:', 0.71887189, 'valid_loss', 0.59439087, 'best_loss', 0.59415317)
# ('Epoch:', 28, 'training:', 0.765625, 'validation:', 0.71287131, 'valid_loss', 0.60022622, 'best_loss', 0.59415317)
# ('Epoch:', 29, 'training:', 0.75, 'validation:', 0.70657068, 'valid_loss', 0.60668981, 'best_loss', 0.59415317)
# ('Epoch:', 30, 'training:', 0.671875, 'validation:', 0.71407139, 'valid_loss', 0.59919143, 'best_loss', 0.59415317)
# ('Epoch:', 31, 'training:', 0.828125, 'validation:', 0.70537055, 'valid_loss', 0.60789198, 'best_loss', 0.59415317)
# ('Epoch:', 32, 'training:', 0.734375, 'validation:', 0.70627064, 'valid_loss', 0.60699189, 'best_loss', 0.59415317)
# ('Epoch:', 33, 'training:', 0.765625, 'validation:', 0.70207024, 'valid_loss', 0.61119676, 'best_loss', 0.59415317)
# ('Epoch:', 34, 'training:', 0.796875, 'validation:', 0.71287131, 'valid_loss', 0.60043293, 'best_loss', 0.59415317)
# ('Epoch:', 35, 'training:', 0.78125, 'validation:', 0.70537055, 'valid_loss', 0.60789186, 'best_loss', 0.59415317)
# ('Epoch:', 36, 'training:', 0.796875, 'validation:', 0.71287131, 'valid_loss', 0.60039127, 'best_loss', 0.59415317)
# ('Epoch:', 37, 'training:', 0.75, 'validation:', 0.7050705, 'valid_loss', 0.60812289, 'best_loss', 0.59415317)
# ('Epoch:', 38, 'training:', 0.75, 'validation:', 0.71977198, 'valid_loss', 0.59359181, 'best_loss', 0.59415317)
# ('Epoch:', 39, 'training:', 0.875, 'validation:', 0.7131713, 'valid_loss', 0.60010237, 'best_loss', 0.59359181)
# ('Epoch:', 40, 'training:', 0.796875, 'validation:', 0.71137112, 'valid_loss', 0.60178208, 'best_loss', 0.59359181)
# ('Epoch:', 41, 'training:', 0.8125, 'validation:', 0.70927095, 'valid_loss', 0.60399169, 'best_loss', 0.59359181)
# ('Epoch:', 42, 'training:', 0.828125, 'validation:', 0.72157216, 'valid_loss', 0.59169066, 'best_loss', 0.59359181)
# ('Epoch:', 43, 'training:', 0.765625, 'validation:', 0.71437144, 'valid_loss', 0.5988906, 'best_loss', 0.59169066)
# ('Epoch:', 44, 'training:', 0.84375, 'validation:', 0.70837086, 'valid_loss', 0.60489166, 'best_loss', 0.59169066)
# ('Epoch:', 45, 'training:', 0.828125, 'validation:', 0.71467149, 'valid_loss', 0.59846032, 'best_loss', 0.59169066)
# ('Epoch:', 46, 'training:', 0.84375, 'validation:', 0.71767175, 'valid_loss', 0.59554476, 'best_loss', 0.59169066)
# ('Epoch:', 47, 'training:', 0.765625, 'validation:', 0.72307229, 'valid_loss', 0.59019053, 'best_loss', 0.59169066)
# ('Epoch:', 48, 'training:', 0.765625, 'validation:', 0.72937292, 'valid_loss', 0.58374488, 'best_loss', 0.59019053)
# ('Epoch:', 49, 'training:', 0.75, 'validation:', 0.72127211, 'valid_loss', 0.59203506, 'best_loss', 0.58374488)
# ('Epoch:', 50, 'training:', 0.890625, 'validation:', 0.70237023, 'valid_loss', 0.61089206, 'best_loss', 0.58374488)
# ('Epoch:', 51, 'training:', 0.890625, 'validation:', 0.71827185, 'valid_loss', 0.59499097, 'best_loss', 0.58374488)
# ('Epoch:', 52, 'training:', 0.78125, 'validation:', 0.71407139, 'valid_loss', 0.59919119, 'best_loss', 0.58374488)
# ('Epoch:', 53, 'training:', 0.8125, 'validation:', 0.71227121, 'valid_loss', 0.60099149, 'best_loss', 0.58374488)
# ('Epoch:', 54, 'training:', 0.78125, 'validation:', 0.70927095, 'valid_loss', 0.60398936, 'best_loss', 0.58374488)
# ('Epoch:', 55, 'training:', 0.90625, 'validation:', 0.69456947, 'valid_loss', 0.61869287, 'best_loss', 0.58374488)
# ('Epoch:', 56, 'training:', 0.828125, 'validation:', 0.70627064, 'valid_loss', 0.60699189, 'best_loss', 0.58374488)
# ('Epoch:', 57, 'training:', 0.84375, 'validation:', 0.69756973, 'valid_loss', 0.6156925, 'best_loss', 0.58374488)
# ('Epoch:', 58, 'training:', 0.84375, 'validation:', 0.71767175, 'valid_loss', 0.59559077, 'best_loss', 0.58374488)
# ('Epoch:', 59, 'training:', 0.796875, 'validation:', 0.70477051, 'valid_loss', 0.6084919, 'best_loss', 0.58374488)
# ('Epoch:', 60, 'training:', 0.875, 'validation:', 0.70267028, 'valid_loss', 0.61059213, 'best_loss', 0.58374488)
# ('Epoch:', 61, 'training:', 0.8125, 'validation:', 0.70627064, 'valid_loss', 0.60699201, 'best_loss', 0.58374488)
# ('Epoch:', 62, 'training:', 0.890625, 'validation:', 0.71587157, 'valid_loss', 0.59739, 'best_loss', 0.58374488)
# ('Epoch:', 63, 'training:', 0.859375, 'validation:', 0.72157216, 'valid_loss', 0.5917908, 'best_loss', 0.58374488)
# ('Epoch:', 64, 'training:', 0.84375, 'validation:', 0.71977198, 'valid_loss', 0.59349072, 'best_loss', 0.58374488)
# ('Epoch:', 65, 'training:', 0.828125, 'validation:', 0.71077108, 'valid_loss', 0.60249144, 'best_loss', 0.58374488)
# ('Epoch:', 66, 'training:', 0.828125, 'validation:', 0.70807081, 'valid_loss', 0.6051932, 'best_loss', 0.58374488)
# ('Epoch:', 67, 'training:', 0.8125, 'validation:', 0.71617162, 'valid_loss', 0.5970912, 'best_loss', 0.58374488)
# ('Epoch:', 68, 'training:', 0.828125, 'validation:', 0.71137112, 'valid_loss', 0.60189164, 'best_loss', 0.58374488)
# Early stopping!
# Training completed in 55.3495935996 minutes
# [CV]  learning_rate=0.01, n_layers=3, n_neurons=150, batch_size=64, total=55.4min
# [CV] learning_rate=0.01, n_layers=3, n_neurons=150, batch_size=64 ....
# ('Epoch:', 0, 'training:', 0.703125, 'validation:', 0.61806178, 'valid_loss', 0.6921761, 'best_loss', inf)
# ('Epoch:', 1, 'training:', 0.703125, 'validation:', 0.63996398, 'valid_loss', 0.67220306, 'best_loss', 0.6921761)
# ('Epoch:', 2, 'training:', 0.765625, 'validation:', 0.65886587, 'valid_loss', 0.65405798, 'best_loss', 0.67220306)
# ('Epoch:', 3, 'training:', 0.796875, 'validation:', 0.6477648, 'valid_loss', 0.665187, 'best_loss', 0.65405798)
# ('Epoch:', 4, 'training:', 0.703125, 'validation:', 0.64656466, 'valid_loss', 0.66633725, 'best_loss', 0.65405798)
# ('Epoch:', 5, 'training:', 0.8125, 'validation:', 0.6651665, 'valid_loss', 0.6478917, 'best_loss', 0.65405798)
# ('Epoch:', 6, 'training:', 0.8125, 'validation:', 0.66636664, 'valid_loss', 0.64667696, 'best_loss', 0.6478917)
# ('Epoch:', 7, 'training:', 0.828125, 'validation:', 0.69966996, 'valid_loss', 0.61354101, 'best_loss', 0.64667696)
# ('Epoch:', 8, 'training:', 0.75, 'validation:', 0.69006902, 'valid_loss', 0.62339544, 'best_loss', 0.61354101)
# ('Epoch:', 9, 'training:', 0.875, 'validation:', 0.67596757, 'valid_loss', 0.63703948, 'best_loss', 0.61354101)
# ('Epoch:', 10, 'training:', 0.765625, 'validation:', 0.66426641, 'valid_loss', 0.64887148, 'best_loss', 0.61354101)
# ('Epoch:', 11, 'training:', 0.71875, 'validation:', 0.67356735, 'valid_loss', 0.6397742, 'best_loss', 0.61354101)
# ('Epoch:', 12, 'training:', 0.78125, 'validation:', 0.67446744, 'valid_loss', 0.63867444, 'best_loss', 0.61354101)
# ('Epoch:', 13, 'training:', 0.765625, 'validation:', 0.68646866, 'valid_loss', 0.62673682, 'best_loss', 0.61354101)
# ('Epoch:', 14, 'training:', 0.71875, 'validation:', 0.68376839, 'valid_loss', 0.62950212, 'best_loss', 0.61354101)
# ('Epoch:', 15, 'training:', 0.8125, 'validation:', 0.71767175, 'valid_loss', 0.59557486, 'best_loss', 0.61354101)
# ('Epoch:', 16, 'training:', 0.703125, 'validation:', 0.7056706, 'valid_loss', 0.60750866, 'best_loss', 0.59557486)
# ('Epoch:', 17, 'training:', 0.75, 'validation:', 0.7179718, 'valid_loss', 0.59517485, 'best_loss', 0.59557486)
# ('Epoch:', 18, 'training:', 0.796875, 'validation:', 0.70807081, 'valid_loss', 0.60512698, 'best_loss', 0.59517485)
# ('Epoch:', 19, 'training:', 0.890625, 'validation:', 0.68946892, 'valid_loss', 0.6237815, 'best_loss', 0.59517485)
# ('Epoch:', 20, 'training:', 0.78125, 'validation:', 0.69756973, 'valid_loss', 0.61564904, 'best_loss', 0.59517485)
# ('Epoch:', 21, 'training:', 0.71875, 'validation:', 0.69846982, 'valid_loss', 0.61473221, 'best_loss', 0.59517485)
# ('Epoch:', 22, 'training:', 0.765625, 'validation:', 0.70237023, 'valid_loss', 0.6108619, 'best_loss', 0.59517485)
# ('Epoch:', 23, 'training:', 0.859375, 'validation:', 0.70027006, 'valid_loss', 0.61299258, 'best_loss', 0.59517485)
# ('Epoch:', 24, 'training:', 0.765625, 'validation:', 0.70297033, 'valid_loss', 0.61029226, 'best_loss', 0.59517485)
# ('Epoch:', 25, 'training:', 0.765625, 'validation:', 0.70357037, 'valid_loss', 0.60967803, 'best_loss', 0.59517485)
# ('Epoch:', 26, 'training:', 0.8125, 'validation:', 0.7008701, 'valid_loss', 0.61226416, 'best_loss', 0.59517485)
# ('Epoch:', 27, 'training:', 0.796875, 'validation:', 0.71017104, 'valid_loss', 0.60309172, 'best_loss', 0.59517485)
# ('Epoch:', 28, 'training:', 0.828125, 'validation:', 0.70267028, 'valid_loss', 0.61040902, 'best_loss', 0.59517485)
# ('Epoch:', 29, 'training:', 0.828125, 'validation:', 0.70927095, 'valid_loss', 0.60395002, 'best_loss', 0.59517485)
# ('Epoch:', 30, 'training:', 0.84375, 'validation:', 0.70837086, 'valid_loss', 0.60489178, 'best_loss', 0.59517485)
# ('Epoch:', 31, 'training:', 0.8125, 'validation:', 0.72187221, 'valid_loss', 0.59127206, 'best_loss', 0.59517485)
# ('Epoch:', 32, 'training:', 0.6875, 'validation:', 0.69456947, 'valid_loss', 0.61870182, 'best_loss', 0.59127206)
# ('Epoch:', 33, 'training:', 0.796875, 'validation:', 0.70357037, 'valid_loss', 0.6096921, 'best_loss', 0.59127206)
# ('Epoch:', 34, 'training:', 0.71875, 'validation:', 0.70987099, 'valid_loss', 0.60339159, 'best_loss', 0.59127206)
# ('Epoch:', 35, 'training:', 0.859375, 'validation:', 0.71587157, 'valid_loss', 0.59749943, 'best_loss', 0.59127206)
# ('Epoch:', 36, 'training:', 0.78125, 'validation:', 0.72307229, 'valid_loss', 0.59016055, 'best_loss', 0.59127206)
# ('Epoch:', 37, 'training:', 0.765625, 'validation:', 0.70297033, 'valid_loss', 0.61029232, 'best_loss', 0.59016055)
# ('Epoch:', 38, 'training:', 0.796875, 'validation:', 0.72097212, 'valid_loss', 0.5922907, 'best_loss', 0.59016055)
# ('Epoch:', 39, 'training:', 0.84375, 'validation:', 0.71527153, 'valid_loss', 0.59799248, 'best_loss', 0.59016055)
# ('Epoch:', 40, 'training:', 0.828125, 'validation:', 0.70057005, 'valid_loss', 0.61269242, 'best_loss', 0.59016055)
# ('Epoch:', 41, 'training:', 0.8125, 'validation:', 0.70387042, 'valid_loss', 0.60939163, 'best_loss', 0.59016055)
